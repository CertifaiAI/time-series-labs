# %% [markdown]
# # 05 - Time Series Anomaly Detection
# This is a lab on time series anomaly detection. We will be using an artificial data courtesy of *Numenta Anomaly Benchmark*, downloaded from https://github.com/numenta/NAB/tree/master/data. This will be simple demonstration on how to perform anomaly detection using autoencoder and how to interpret it.

# %%
# Importing libraries
import numpy as np
import pandas as pd
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt

# %% [markdown]
# ## Anomaly Detection using Autoencoder

# %% [markdown]
# ### Load the data
# The characteristics of NAB dataset is that it is consist of artifical timeseries data with labeled anomalies. Since this is a time series data, the data are ordered, timestamped, single-valued metrics.
#
# Inside NAB, there are quite a number of datasets. However, for demonstration sake, we will just use the **art_daily_small_noise.csv** dataset for training and the **art_daily_jumpsup.csv** file for testing. The idea is that the users, through this tutorial, can get a glimpse of how anomaly detection actually works, and how to use deep learning to detect them.

# %%
# this is one way of loading data on the fly, just by specifying the URL
master_url_root = "https://raw.githubusercontent.com/numenta/NAB/master/data/"

df_small_noise_url_suffix = "artificialNoAnomaly/art_daily_small_noise.csv"
df_small_noise_url = master_url_root + df_small_noise_url_suffix
df_small_noise = pd.read_csv(
    df_small_noise_url, parse_dates=True, index_col="timestamp"
)

df_daily_jumpsup_url_suffix = "artificialWithAnomaly/art_daily_jumpsup.csv"
df_daily_jumpsup_url = master_url_root + df_daily_jumpsup_url_suffix
df_daily_jumpsup = pd.read_csv(
    df_daily_jumpsup_url, parse_dates=True, index_col="timestamp"
)

# %% [markdown]
# ### Data Exploration
# Let's do some exploration and see what nugget can we find out of this dataset!

# %%
print(df_small_noise.head())
print(df_daily_jumpsup.head())
# Out:
#                          value
# timestamp
# 2014-04-01 00:00:00  18.324919
# 2014-04-01 00:05:00  21.970327
# 2014-04-01 00:10:00  18.624806
# 2014-04-01 00:15:00  21.953684
# 2014-04-01 00:20:00  21.909120
#                          value
# timestamp
# 2014-04-01 00:00:00  19.761252
# 2014-04-01 00:05:00  20.500833
# 2014-04-01 00:10:00  19.961641
# 2014-04-01 00:15:00  21.490266
# 2014-04-01 00:20:00  20.187739

# %% [markdown]
# ### Data Visualization
# A picture is worth more than a thousand words! This applies to the situation here, too. Visuals can efficiently summarize multiple information in a dataset and present them in an intuitive manner.

# %% [markdown]
# #### a) Normal Time Series
# Let's plot the dataset that is explicitly stated that there are no anomalous behaviours first. It is going to be our training set for this tutorial. Can you find any anomalous behaviour in the visual below?

# %%
fig, ax = plt.subplots()
print(fig, ax)
df_small_noise.plot(legend=False, ax=ax)
plt.show()
# Out:
# Figure(432x288) AxesSubplot(0.125,0.125;0.775x0.755)

# %% [markdown]
# You got it right! It appears to be without anomaly for this set of data.

# %% [markdown]
# #### b) Anomalous Time Series
# Let's plot another dataset which is explicitly stated that there is anomalous behaviour. It is going to be our testing set for this tutorial to check whether our model can correctly identify anomalous behaviour. Can you identify any anomalous behaviour in the visual below?

# %%
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
plt.show()

# %% [markdown]
# ### Pre-processing for Training Set
# Since the data is collected at 5-min interval, this means that we have a total of 4032 data points collected for this dataset (since 24 hour * 60 minutes / 5 minutes = 288 data point per day, and the data is collected for a duration of 14 days.
# For the sake of science, let us verify this!

# %%
print(f"Number of observations for training dataset: {df_daily_jumpsup.shape[0]}")
print(df_daily_jumpsup.tail())
# Out:
# Number of observations for training dataset: 4032
#                          value
# timestamp
# 2014-04-14 23:35:00  18.074649
# 2014-04-14 23:40:00  21.002014
# 2014-04-14 23:45:00  20.566713
# 2014-04-14 23:50:00  18.254193
# 2014-04-14 23:55:00  21.863147

# %% [markdown]
# Normalization is vital for deep learning model building. Let us not forget to implement this step too! For the spirit of experimentation, let us try to implement this without using Scikit-learn too.

# %%
# performing normalization
training_mean = df_small_noise.mean()
training_std = df_small_noise.std()
training_set = (df_small_noise - training_mean) / training_std
training_set[:10]
# Out:
#                         value
# timestamp
# 2014-04-01 00:00:00 -0.858829
# 2014-04-01 00:05:00 -0.728993
# 2014-04-01 00:10:00 -0.848148
# 2014-04-01 00:15:00 -0.729586
# 2014-04-01 00:20:00 -0.731173
# 2014-04-01 00:25:00 -0.757310
# 2014-04-01 00:30:00 -0.776456
# 2014-04-01 00:35:00 -0.788084
# 2014-04-01 00:40:00 -0.747012
# 2014-04-01 00:45:00 -0.829166

# %%
# Standardization
from sklearn import preprocessing

scaler = preprocessing.StandardScaler().fit(df_small_noise)
training_set = scaler.transform(df_small_noise)
training_set[:10]
# Out:
# array([[-0.85893509],
#        [-0.72908344],
#        [-0.84825292],
#        [-0.72967628],
#        [-0.73126368],
#        [-0.75740377],
#        [-0.77655271],
#        [-0.78818154],
#        [-0.74710465],
#        [-0.82926884]])

# %% [markdown]
# It is vital to prepare our data into a form that is ingestible by our model easily, and time series requires this extra step of turning them into a sequence, which we will demonstrate below.

# %%
# defining a function to create sequences with data values 
# and time steps input

time_steps = 288

def create_sequences(values, time_steps = time_steps):
    output = []
    for i in range(len(values) - time_steps):
        output.append(values[i : (i + time_steps)])
    return torch.Tensor(output)

# %%
# Calling the create_sequence function

x_train = create_sequences(training_set)
print(f"Shape of training dataset: {x_train.shape}")
x_train.dtype
# Out:
# Shape of training dataset: torch.Size([3744, 288, 1])
# torch.float32

# %% [markdown]
# Do you know why the training set has a torch.Size of (3744, 288, 1)?\
# Because we transformed the data into 3744 rows of observations, each observation having 288 sequence length with 1 feature only.\
# Next, we will convert it into Pytorch Dataset instance so that we can turn it into an interator subsequently.

# %%
class PytorchDataset(torch.utils.data.dataset.Dataset):
    def __init__(self, x):
        self.x = torch.Tensor(x)
    
    def __len__(self):
        return len(self.x)
    
    def __getitem__(self, idx):
        return self.x[idx]

# %%
# calling the object to convert training set into Pytorch Dataset instance

train_dataset = PytorchDataset(x_train)

# %%
# Sanity check

print(train_dataset[0][0][0])
print(len(train_dataset))
print(len(train_dataset[0]))
print(len(train_dataset[0][0]))
# Out:
# tensor(-0.8589)
# 3744
# 288
# 1

# %% [markdown]
# Looks like our transformation work as expected! Let's continue and convert it to a DataLoader then.

# %%
# let's use DataLoader built-in for Pytorch to perform batching
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                            batch_size=128,
                                            shuffle=False)

# %%
# let's check again by printing out one batch of data

dataiter = iter(train_loader)
sample = next(dataiter)
print(sample.size())
print()
# Out:
# torch.Size([128, 288, 1])

# %% [markdown]
# Having an iterator now, we are ready to build our deep learning model for some rock and roll action (like, finally) ! We will be using a convolutional autoencoder for the purpose of anomaly detection.

# %%
# let's configure some hyperparameters

epochs = 50
learning_rate = 0.001
random_seed = 42
torch.manual_seed(random_seed)

# %%
# define the NN architecture

class ConvAutoencoder(nn.Module):
    def __init__(self):
        super(ConvAutoencoder, self).__init__()
        ## encoder layers ##
        # conv layer (depth from 3 --> 16), 3x3 kernels
        self.conv1d1 = nn.Conv1d(288, 32, 7, stride=2, padding=3)
        self.dropout1 = nn.Dropout(p=0.2)
        self.conv1d2 = nn.Conv1d(32, 16, 7, stride=2, padding=3)
        self.convtranspose1d1 = nn.ConvTranspose1d(16, 16, 7, stride=2, padding=3)
        self.dropout2 = nn.Dropout(p=0.2)
        self.convtranspose1d2 = nn.ConvTranspose1d(16, 32, 7, stride=2, padding=3)
        self.convtranspose1d3 = nn.ConvTranspose1d(32, 288, 7, stride=2, padding=3)

    def forward(self, x):
        ## encode ##
        # add hidden layers with relu activation function
        x = F.relu(self.conv1d1(x))
        # add second hidden layer
        x = F.relu(self.conv1d2(x))
        x = F.relu(self.convtranspose1d1(x))
        x = F.relu(self.convtranspose1d2(x))
        x = self.convtranspose1d3(x)
                
        return x

# initialize the NN
model = ConvAutoencoder()
print(model)
# Out:
# ConvAutoencoder(
#   (conv1d1): Conv1d(288, 32, kernel_size=(7,), stride=(2,), padding=(3,))
#   (dropout1): Dropout(p=0.2, inplace=False)
#   (conv1d2): Conv1d(32, 16, kernel_size=(7,), stride=(2,), padding=(3,))
#   (convtranspose1d1): ConvTranspose1d(16, 16, kernel_size=(7,), stride=(2,), padding=(3,))
#   (dropout2): Dropout(p=0.2, inplace=False)
#   (convtranspose1d2): ConvTranspose1d(16, 32, kernel_size=(7,), stride=(2,), padding=(3,))
#   (convtranspose1d3): ConvTranspose1d(32, 288, kernel_size=(7,), stride=(2,), padding=(3,))
# )

# %%
# the keeping of shape is important for autoencoder, so let us try to print out shape for each layer

conv1d1 = nn.Conv1d(288, 32, 7, stride=2, padding=3)
dropout1 = nn.Dropout(p=0.2)
conv1d2 = nn.Conv1d(32, 16, 7, stride=2, padding=3)
convtranspose1d1 = nn.ConvTranspose1d(16, 16, 7, stride=2, padding=3)
dropout2 = nn.Dropout(p=0.2)
convtranspose1d2 = nn.ConvTranspose1d(16, 32, 7, stride=2, padding=3)
convtranspose1d3 = nn.ConvTranspose1d(32, 288, 7, stride=2, padding=3)

out = conv1d1(sample)
print(out.shape)
out = conv1d2(out)
print(out.shape)
out = convtranspose1d1(out)
print(out.shape)
out = convtranspose1d2(out)
print(out.shape)
out = convtranspose1d3(out)
print(out.shape)
# Out:
# torch.Size([128, 32, 1])
# torch.Size([128, 16, 1])
# torch.Size([128, 16, 1])
# torch.Size([128, 32, 1])
# torch.Size([128, 288, 1])

# %%
# let's set loss and optimization function
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=learning_rate)

# %%
# finally we can start to train
n_total_steps = len(train_loader)
print(n_total_steps)

for epoch in range(epochs):
    for i, x in enumerate(train_loader):          
        # forward pass
        outputs = model(x)
        loss = criterion(outputs, x) # we are using x as both the input and target because we are trying to measure the loss of our reconstruction model
        
        # backward pass
        optimizer.zero_grad() # this is to clear the parameters, done before each backward pass
        loss.backward()
        optimizer.step()
        
        # print out the training performance
        if (i+1) % 5 == 0:
            print (f'Epoch [{epoch+1}/{epochs}], Step [{i+1}/{n_total_steps}], Loss: {loss.item():10.4f}')
# Out:
# 30
# Epoch [1/50], Step [5/30], Loss:     0.9862
# Epoch [1/50], Step [10/30], Loss:     1.0050
# Epoch [1/50], Step [15/30], Loss:     1.0078
# Epoch [1/50], Step [20/30], Loss:     1.0069
# Epoch [1/50], Step [25/30], Loss:     0.9974
# Epoch [1/50], Step [30/30], Loss:     1.0040
# Epoch [2/50], Step [5/30], Loss:     0.9723
# Epoch [2/50], Step [10/30], Loss:     0.9255
# Epoch [2/50], Step [15/30], Loss:     0.8650
# Epoch [2/50], Step [20/30], Loss:     0.9319
# Epoch [2/50], Step [25/30], Loss:     0.8355
# Epoch [2/50], Step [30/30], Loss:     0.6847
# Epoch [3/50], Step [5/30], Loss:     0.5920
# Epoch [3/50], Step [10/30], Loss:     0.5639
# Epoch [3/50], Step [15/30], Loss:     0.6409
# Epoch [3/50], Step [20/30], Loss:     0.6977
# Epoch [3/50], Step [25/30], Loss:     0.5446
# Epoch [3/50], Step [30/30], Loss:     0.4143
# Epoch [4/50], Step [5/30], Loss:     0.4829
# Epoch [4/50], Step [10/30], Loss:     0.4502
# Epoch [4/50], Step [15/30], Loss:     0.6102
# Epoch [4/50], Step [20/30], Loss:     0.6820
# Epoch [4/50], Step [25/30], Loss:     0.3549
# Epoch [4/50], Step [30/30], Loss:     0.2083
# Epoch [5/50], Step [5/30], Loss:     0.2026
# Epoch [5/50], Step [10/30], Loss:     0.2296
# Epoch [5/50], Step [15/30], Loss:     0.3720
# Epoch [5/50], Step [20/30], Loss:     0.3408
# Epoch [5/50], Step [25/30], Loss:     0.2286
# Epoch [5/50], Step [30/30], Loss:     0.2181
# Epoch [6/50], Step [5/30], Loss:     0.2094
# Epoch [6/50], Step [10/30], Loss:     0.2249
# Epoch [6/50], Step [15/30], Loss:     0.2397
# Epoch [6/50], Step [20/30], Loss:     0.2226
# Epoch [6/50], Step [25/30], Loss:     0.2143
# Epoch [6/50], Step [30/30], Loss:     0.2001
# Epoch [7/50], Step [5/30], Loss:     0.2119
# Epoch [7/50], Step [10/30], Loss:     0.2148
# Epoch [7/50], Step [15/30], Loss:     0.2121
# Epoch [7/50], Step [20/30], Loss:     0.1991
# Epoch [7/50], Step [25/30], Loss:     0.1897
# Epoch [7/50], Step [30/30], Loss:     0.1879
# Epoch [8/50], Step [5/30], Loss:     0.1832
# Epoch [8/50], Step [10/30], Loss:     0.1802
# Epoch [8/50], Step [15/30], Loss:     0.1783
# Epoch [8/50], Step [20/30], Loss:     0.1669
# Epoch [8/50], Step [25/30], Loss:     0.1579
# Epoch [8/50], Step [30/30], Loss:     0.1614
# Epoch [9/50], Step [5/30], Loss:     0.1519
# Epoch [9/50], Step [10/30], Loss:     0.1453
# Epoch [9/50], Step [15/30], Loss:     0.1470
# Epoch [9/50], Step [20/30], Loss:     0.1352
# Epoch [9/50], Step [25/30], Loss:     0.1288
# Epoch [9/50], Step [30/30], Loss:     0.1302
# Epoch [10/50], Step [5/30], Loss:     0.1290
# Epoch [10/50], Step [10/30], Loss:     0.1246
# Epoch [10/50], Step [15/30], Loss:     0.1311
# Epoch [10/50], Step [20/30], Loss:     0.1202
# Epoch [10/50], Step [25/30], Loss:     0.1163
# Epoch [10/50], Step [30/30], Loss:     0.1159
# Epoch [11/50], Step [5/30], Loss:     0.1219
# Epoch [11/50], Step [10/30], Loss:     0.1200
# Epoch [11/50], Step [15/30], Loss:     0.1275
# Epoch [11/50], Step [20/30], Loss:     0.1160
# Epoch [11/50], Step [25/30], Loss:     0.1116
# Epoch [11/50], Step [30/30], Loss:     0.1122
# Epoch [12/50], Step [5/30], Loss:     0.1186
# Epoch [12/50], Step [10/30], Loss:     0.1180
# Epoch [12/50], Step [15/30], Loss:     0.1250
# Epoch [12/50], Step [20/30], Loss:     0.1126
# Epoch [12/50], Step [25/30], Loss:     0.1077
# Epoch [12/50], Step [30/30], Loss:     0.1086
# Epoch [13/50], Step [5/30], Loss:     0.1156
# Epoch [13/50], Step [10/30], Loss:     0.1162
# Epoch [13/50], Step [15/30], Loss:     0.1227
# Epoch [13/50], Step [20/30], Loss:     0.1090
# Epoch [13/50], Step [25/30], Loss:     0.1037
# Epoch [13/50], Step [30/30], Loss:     0.1052
# Epoch [14/50], Step [5/30], Loss:     0.1123
# Epoch [14/50], Step [10/30], Loss:     0.1141
# Epoch [14/50], Step [15/30], Loss:     0.1202
# Epoch [14/50], Step [20/30], Loss:     0.1052
# Epoch [14/50], Step [25/30], Loss:     0.0994
# Epoch [14/50], Step [30/30], Loss:     0.1016
# Epoch [15/50], Step [5/30], Loss:     0.1086
# Epoch [15/50], Step [10/30], Loss:     0.1116
# Epoch [15/50], Step [15/30], Loss:     0.1176
# Epoch [15/50], Step [20/30], Loss:     0.1010
# Epoch [15/50], Step [25/30], Loss:     0.0948
# Epoch [15/50], Step [30/30], Loss:     0.0975
# Epoch [16/50], Step [5/30], Loss:     0.1048
# Epoch [16/50], Step [10/30], Loss:     0.1089
# Epoch [16/50], Step [15/30], Loss:     0.1147
# Epoch [16/50], Step [20/30], Loss:     0.0965
# Epoch [16/50], Step [25/30], Loss:     0.0903
# Epoch [16/50], Step [30/30], Loss:     0.0931
# Epoch [17/50], Step [5/30], Loss:     0.1010
# Epoch [17/50], Step [10/30], Loss:     0.1057
# Epoch [17/50], Step [15/30], Loss:     0.1114
# Epoch [17/50], Step [20/30], Loss:     0.0918
# Epoch [17/50], Step [25/30], Loss:     0.0858
# Epoch [17/50], Step [30/30], Loss:     0.0880
# Epoch [18/50], Step [5/30], Loss:     0.0968
# Epoch [18/50], Step [10/30], Loss:     0.1020
# Epoch [18/50], Step [15/30], Loss:     0.1078
# Epoch [18/50], Step [20/30], Loss:     0.0870
# Epoch [18/50], Step [25/30], Loss:     0.0811
# Epoch [18/50], Step [30/30], Loss:     0.0836
# Epoch [19/50], Step [5/30], Loss:     0.0924
# Epoch [19/50], Step [10/30], Loss:     0.0975
# Epoch [19/50], Step [15/30], Loss:     0.1034
# Epoch [19/50], Step [20/30], Loss:     0.0823
# Epoch [19/50], Step [25/30], Loss:     0.0768
# Epoch [19/50], Step [30/30], Loss:     0.0799
# Epoch [20/50], Step [5/30], Loss:     0.0880
# Epoch [20/50], Step [10/30], Loss:     0.0928
# Epoch [20/50], Step [15/30], Loss:     0.0986
# Epoch [20/50], Step [20/30], Loss:     0.0780
# Epoch [20/50], Step [25/30], Loss:     0.0729
# Epoch [20/50], Step [30/30], Loss:     0.0763
# Epoch [21/50], Step [5/30], Loss:     0.0836
# Epoch [21/50], Step [10/30], Loss:     0.0877
# Epoch [21/50], Step [15/30], Loss:     0.0933
# Epoch [21/50], Step [20/30], Loss:     0.0742
# Epoch [21/50], Step [25/30], Loss:     0.0698
# Epoch [21/50], Step [30/30], Loss:     0.0730
# Epoch [22/50], Step [5/30], Loss:     0.0798
# Epoch [22/50], Step [10/30], Loss:     0.0826
# Epoch [22/50], Step [15/30], Loss:     0.0879
# Epoch [22/50], Step [20/30], Loss:     0.0711
# Epoch [22/50], Step [25/30], Loss:     0.0675
# Epoch [22/50], Step [30/30], Loss:     0.0703
# Epoch [23/50], Step [5/30], Loss:     0.0771
# Epoch [23/50], Step [10/30], Loss:     0.0779
# Epoch [23/50], Step [15/30], Loss:     0.0832
# Epoch [23/50], Step [20/30], Loss:     0.0691
# Epoch [23/50], Step [25/30], Loss:     0.0672
# Epoch [23/50], Step [30/30], Loss:     0.0703
# Epoch [24/50], Step [5/30], Loss:     0.0860
# Epoch [24/50], Step [10/30], Loss:     0.0878
# Epoch [24/50], Step [15/30], Loss:     0.0802
# Epoch [24/50], Step [20/30], Loss:     0.0678
# Epoch [24/50], Step [25/30], Loss:     0.0645
# Epoch [24/50], Step [30/30], Loss:     0.0677
# Epoch [25/50], Step [5/30], Loss:     0.0730
# Epoch [25/50], Step [10/30], Loss:     0.0704
# Epoch [25/50], Step [15/30], Loss:     0.0762
# Epoch [25/50], Step [20/30], Loss:     0.0659
# Epoch [25/50], Step [25/30], Loss:     0.0635
# Epoch [25/50], Step [30/30], Loss:     0.0667
# Epoch [26/50], Step [5/30], Loss:     0.0708
# Epoch [26/50], Step [10/30], Loss:     0.0683
# Epoch [26/50], Step [15/30], Loss:     0.0738
# Epoch [26/50], Step [20/30], Loss:     0.0649
# Epoch [26/50], Step [25/30], Loss:     0.0624
# Epoch [26/50], Step [30/30], Loss:     0.0656
# Epoch [27/50], Step [5/30], Loss:     0.0694
# Epoch [27/50], Step [10/30], Loss:     0.0664
# Epoch [27/50], Step [15/30], Loss:     0.0720
# Epoch [27/50], Step [20/30], Loss:     0.0641
# Epoch [27/50], Step [25/30], Loss:     0.0617
# Epoch [27/50], Step [30/30], Loss:     0.0647
# Epoch [28/50], Step [5/30], Loss:     0.0688
# Epoch [28/50], Step [10/30], Loss:     0.0656
# Epoch [28/50], Step [15/30], Loss:     0.0707
# Epoch [28/50], Step [20/30], Loss:     0.0635
# Epoch [28/50], Step [25/30], Loss:     0.0609
# Epoch [28/50], Step [30/30], Loss:     0.0636
# Epoch [29/50], Step [5/30], Loss:     0.0676
# Epoch [29/50], Step [10/30], Loss:     0.0639
# Epoch [29/50], Step [15/30], Loss:     0.0696
# Epoch [29/50], Step [20/30], Loss:     0.0626
# Epoch [29/50], Step [25/30], Loss:     0.0603
# Epoch [29/50], Step [30/30], Loss:     0.0626
# Epoch [30/50], Step [5/30], Loss:     0.0675
# Epoch [30/50], Step [10/30], Loss:     0.0634
# Epoch [30/50], Step [15/30], Loss:     0.0689
# Epoch [30/50], Step [20/30], Loss:     0.0619
# Epoch [30/50], Step [25/30], Loss:     0.0607
# Epoch [30/50], Step [30/30], Loss:     0.0633
# Epoch [31/50], Step [5/30], Loss:     0.0785
# Epoch [31/50], Step [10/30], Loss:     0.0690
# Epoch [31/50], Step [15/30], Loss:     0.0686
# Epoch [31/50], Step [20/30], Loss:     0.0624
# Epoch [31/50], Step [25/30], Loss:     0.0593
# Epoch [31/50], Step [30/30], Loss:     0.0615
# Epoch [32/50], Step [5/30], Loss:     0.0659
# Epoch [32/50], Step [10/30], Loss:     0.0616
# Epoch [32/50], Step [15/30], Loss:     0.0674
# Epoch [32/50], Step [20/30], Loss:     0.0605
# Epoch [32/50], Step [25/30], Loss:     0.0585
# Epoch [32/50], Step [30/30], Loss:     0.0605
# Epoch [33/50], Step [5/30], Loss:     0.0648
# Epoch [33/50], Step [10/30], Loss:     0.0610
# Epoch [33/50], Step [15/30], Loss:     0.0666
# Epoch [33/50], Step [20/30], Loss:     0.0600
# Epoch [33/50], Step [25/30], Loss:     0.0580
# Epoch [33/50], Step [30/30], Loss:     0.0598
# Epoch [34/50], Step [5/30], Loss:     0.0643
# Epoch [34/50], Step [10/30], Loss:     0.0604
# Epoch [34/50], Step [15/30], Loss:     0.0660
# Epoch [34/50], Step [20/30], Loss:     0.0595
# Epoch [34/50], Step [25/30], Loss:     0.0575
# Epoch [34/50], Step [30/30], Loss:     0.0593
# Epoch [35/50], Step [5/30], Loss:     0.0642
# Epoch [35/50], Step [10/30], Loss:     0.0602
# Epoch [35/50], Step [15/30], Loss:     0.0655
# Epoch [35/50], Step [20/30], Loss:     0.0592
# Epoch [35/50], Step [25/30], Loss:     0.0570
# Epoch [35/50], Step [30/30], Loss:     0.0587
# Epoch [36/50], Step [5/30], Loss:     0.0640
# Epoch [36/50], Step [10/30], Loss:     0.0600
# Epoch [36/50], Step [15/30], Loss:     0.0651
# Epoch [36/50], Step [20/30], Loss:     0.0587
# Epoch [36/50], Step [25/30], Loss:     0.0565
# Epoch [36/50], Step [30/30], Loss:     0.0581
# Epoch [37/50], Step [5/30], Loss:     0.0630
# Epoch [37/50], Step [10/30], Loss:     0.0593
# Epoch [37/50], Step [15/30], Loss:     0.0645
# Epoch [37/50], Step [20/30], Loss:     0.0581
# Epoch [37/50], Step [25/30], Loss:     0.0561
# Epoch [37/50], Step [30/30], Loss:     0.0574
# Epoch [38/50], Step [5/30], Loss:     0.0622
# Epoch [38/50], Step [10/30], Loss:     0.0584
# Epoch [38/50], Step [15/30], Loss:     0.0640
# Epoch [38/50], Step [20/30], Loss:     0.0574
# Epoch [38/50], Step [25/30], Loss:     0.0556
# Epoch [38/50], Step [30/30], Loss:     0.0569
# Epoch [39/50], Step [5/30], Loss:     0.0619
# Epoch [39/50], Step [10/30], Loss:     0.0580
# Epoch [39/50], Step [15/30], Loss:     0.0636
# Epoch [39/50], Step [20/30], Loss:     0.0569
# Epoch [39/50], Step [25/30], Loss:     0.0552
# Epoch [39/50], Step [30/30], Loss:     0.0564
# Epoch [40/50], Step [5/30], Loss:     0.0617
# Epoch [40/50], Step [10/30], Loss:     0.0577
# Epoch [40/50], Step [15/30], Loss:     0.0632
# Epoch [40/50], Step [20/30], Loss:     0.0565
# Epoch [40/50], Step [25/30], Loss:     0.0563
# Epoch [40/50], Step [30/30], Loss:     0.0581
# Epoch [41/50], Step [5/30], Loss:     0.0802
# Epoch [41/50], Step [10/30], Loss:     0.0693
# Epoch [41/50], Step [15/30], Loss:     0.0652
# Epoch [41/50], Step [20/30], Loss:     0.0590
# Epoch [41/50], Step [25/30], Loss:     0.0550
# Epoch [41/50], Step [30/30], Loss:     0.0557
# Epoch [42/50], Step [5/30], Loss:     0.0608
# Epoch [42/50], Step [10/30], Loss:     0.0570
# Epoch [42/50], Step [15/30], Loss:     0.0624
# Epoch [42/50], Step [20/30], Loss:     0.0556
# Epoch [42/50], Step [25/30], Loss:     0.0540
# Epoch [42/50], Step [30/30], Loss:     0.0551
# Epoch [43/50], Step [5/30], Loss:     0.0602
# Epoch [43/50], Step [10/30], Loss:     0.0562
# Epoch [43/50], Step [15/30], Loss:     0.0618
# Epoch [43/50], Step [20/30], Loss:     0.0552
# Epoch [43/50], Step [25/30], Loss:     0.0536
# Epoch [43/50], Step [30/30], Loss:     0.0547
# Epoch [44/50], Step [5/30], Loss:     0.0598
# Epoch [44/50], Step [10/30], Loss:     0.0558
# Epoch [44/50], Step [15/30], Loss:     0.0614
# Epoch [44/50], Step [20/30], Loss:     0.0548
# Epoch [44/50], Step [25/30], Loss:     0.0533
# Epoch [44/50], Step [30/30], Loss:     0.0545
# Epoch [45/50], Step [5/30], Loss:     0.0598
# Epoch [45/50], Step [10/30], Loss:     0.0556
# Epoch [45/50], Step [15/30], Loss:     0.0610
# Epoch [45/50], Step [20/30], Loss:     0.0546
# Epoch [45/50], Step [25/30], Loss:     0.0530
# Epoch [45/50], Step [30/30], Loss:     0.0543
# Epoch [46/50], Step [5/30], Loss:     0.0601
# Epoch [46/50], Step [10/30], Loss:     0.0558
# Epoch [46/50], Step [15/30], Loss:     0.0607
# Epoch [46/50], Step [20/30], Loss:     0.0544
# Epoch [46/50], Step [25/30], Loss:     0.0527
# Epoch [46/50], Step [30/30], Loss:     0.0541
# Epoch [47/50], Step [5/30], Loss:     0.0600
# Epoch [47/50], Step [10/30], Loss:     0.0558
# Epoch [47/50], Step [15/30], Loss:     0.0604
# Epoch [47/50], Step [20/30], Loss:     0.0541
# Epoch [47/50], Step [25/30], Loss:     0.0523
# Epoch [47/50], Step [30/30], Loss:     0.0537
# Epoch [48/50], Step [5/30], Loss:     0.0591
# Epoch [48/50], Step [10/30], Loss:     0.0551
# Epoch [48/50], Step [15/30], Loss:     0.0598
# Epoch [48/50], Step [20/30], Loss:     0.0535
# Epoch [48/50], Step [25/30], Loss:     0.0520
# Epoch [48/50], Step [30/30], Loss:     0.0533
# Epoch [49/50], Step [5/30], Loss:     0.0583
# Epoch [49/50], Step [10/30], Loss:     0.0541
# Epoch [49/50], Step [15/30], Loss:     0.0593
# Epoch [49/50], Step [20/30], Loss:     0.0530
# Epoch [49/50], Step [25/30], Loss:     0.0517
# Epoch [49/50], Step [30/30], Loss:     0.0529
# Epoch [50/50], Step [5/30], Loss:     0.0581
# Epoch [50/50], Step [10/30], Loss:     0.0537
# Epoch [50/50], Step [15/30], Loss:     0.0589
# Epoch [50/50], Step [20/30], Loss:     0.0527
# Epoch [50/50], Step [25/30], Loss:     0.0514
# Epoch [50/50], Step [30/30], Loss:     0.0527

# %% [markdown]
# ### Visualising Results for Model Training
# Ideally, we should use Tensorboard for visualizing the training process. However, that's tutorial for another day!

# %% [markdown]
# ### Anomaly Detection
#
# Recall our anomaly detection model works. We developed a reconstruction model to generate a normal dataset without any anomalous data instances. Next, we need to determine a threshold in order to classify the anomalous points. Finally, we will detect anomalies by fitting our model to the test dataset. So, the steps are summarized below:
#
# 1. Compute MAE loss on training samples for our model.
# 2. Identify the maximum MAE loss, i.e. the worst performance by our model in its attempt to reconstruct the model. Let's use this as the threshold for anomaly detection (assumption is that this model is
#     unable to generate the normal distribution of data, thus this threshold is also able to rather accurately label anomalous data.
# 3. Label sample with reconstruction loss more than threshold as anomaly. If reconstruction loss greater than this threshold value, let's infer that the reconstruction model has encountered data behaviours that is abnormal.

# %%
with torch.no_grad():
    x_train_pred = model(x_train)
    train_mae_loss = np.mean(np.abs((x_train_pred - x_train).numpy()), axis=1)
                         
plt.hist(train_mae_loss, bins=50)
plt.xlabel("Train MAE loss")
plt.ylabel("No. of samples")
plt.show()

threshold = np.max(train_mae_loss)
print(f"The threshold for reconstruction error is: {threshold}")
# Out:
# The threshold for reconstruction error is: 0.20177608728408813

# %% [markdown]
# ### Comparison of Reconstruction
# As a final step, we will compare the reconstruction performed by our model for 288 timesteps from the start of our training set.

# %%
plt.plot(x_train[0])
plt.plot(x_train_pred[0])
plt.show()

# %% [markdown]
# ### Pre-processing of Test Data
# Let us also do the necessary pre-processing for our test data.

# %%
# why use training mean and std???
test_set = scaler.transform(df_daily_jumpsup)
fig, ax = plt.subplots()
plt.plot(test_set)
plt.show()

# Calling create_sequence function to transform data
x_test = create_sequences(test_set)
print(f"Shape of test input: {x_test.shape}")
# Out:
# Shape of test input: torch.Size([3744, 288, 1])

# %%
# Compute MAE loss for test set
with torch.no_grad():
    x_test_pred = model(x_test)
    test_mae_loss = np.mean(np.abs((x_test_pred - x_test).numpy()), axis=1)
    test_mae_loss = test_mae_loss.reshape((-1))

# Visualizing loss
plt.hist(test_mae_loss, bins=50)
plt.xlabel("Loss (MAE) for test set")
plt.ylabel("No. of samples")
plt.show()

# %% [markdown]
# ### Anomaly Detection
# Remember, if the the loss is greater than the threshold, we will label this data as anomaly, and subsequently getting its index in the dataset

# %%
anomalies = test_mae_loss > threshold
print(f"Total of anomaly samples: {np.sum(anomalies)}")
print(f"Indices of anomaly samples: {np.where(anomalies)}")
# Out:
# Total of anomaly samples: 385
# Indices of anomaly samples: (array([2706, 2707, 2708, 2709, 2710, 2711, 2712, 2713, 2714, 2715, 2716,
#        2717, 2718, 2719, 2720, 2721, 2722, 2723, 2724, 2725, 2726, 2727,
#        2728, 2729, 2730, 2731, 2732, 2733, 2734, 2735, 2736, 2737, 2738,
#        2739, 2740, 2741, 2742, 2743, 2744, 2745, 2746, 2747, 2748, 2749,
#        2750, 2751, 2752, 2753, 2754, 2755, 2756, 2757, 2758, 2759, 2760,
#        2761, 2762, 2763, 2764, 2765, 2766, 2767, 2768, 2769, 2770, 2771,
#        2772, 2773, 2774, 2775, 2776, 2777, 2778, 2779, 2780, 2781, 2782,
#        2783, 2784, 2785, 2786, 2787, 2788, 2789, 2790, 2791, 2792, 2793,
#        2794, 2795, 2796, 2797, 2798, 2799, 2800, 2801, 2802, 2803, 2804,
#        2805, 2806, 2807, 2808, 2809, 2810, 2811, 2812, 2813, 2814, 2815,
#        2816, 2817, 2818, 2819, 2820, 2821, 2822, 2823, 2824, 2825, 2826,
#        2827, 2828, 2829, 2830, 2831, 2832, 2833, 2834, 2835, 2836, 2837,
#        2838, 2839, 2840, 2841, 2842, 2843, 2844, 2845, 2846, 2847, 2848,
#        2849, 2850, 2851, 2852, 2853, 2854, 2855, 2856, 2857, 2858, 2859,
#        2860, 2861, 2862, 2863, 2864, 2865, 2866, 2867, 2868, 2869, 2870,
#        2871, 2872, 2873, 2874, 2875, 2876, 2877, 2878, 2879, 2880, 2881,
#        2882, 2883, 2884, 2885, 2886, 2887, 2888, 2889, 2890, 2891, 2892,
#        2893, 2894, 2895, 2896, 2897, 2898, 2899, 2900, 2901, 2902, 2903,
#        2904, 2905, 2906, 2907, 2908, 2909, 2910, 2911, 2912, 2913, 2914,
#        2915, 2916, 2917, 2918, 2919, 2920, 2921, 2922, 2923, 2924, 2925,
#        2926, 2927, 2928, 2929, 2930, 2931, 2932, 2933, 2934, 2935, 2936,
#        2937, 2938, 2939, 2940, 2941, 2942, 2943, 2944, 2945, 2946, 2947,
#        2948, 2949, 2950, 2951, 2952, 2953, 2954, 2955, 2956, 2957, 2958,
#        2959, 2960, 2961, 2962, 2963, 2964, 2965, 2966, 2967, 2968, 2969,
#        2970, 2971, 2972, 2973, 2974, 2975, 2976, 2977, 2978, 2979, 2980,
#        2981, 2982, 2983, 2984, 2985, 2986, 2987, 2988, 2989, 2990, 2991,
#        2992, 2993, 2994, 2995, 2996, 2997, 2998, 2999, 3000, 3001, 3002,
#        3003, 3004, 3005, 3006, 3007, 3008, 3009, 3010, 3011, 3012, 3013,
#        3014, 3015, 3016, 3017, 3018, 3019, 3020, 3021, 3022, 3023, 3024,
#        3025, 3026, 3027, 3028, 3029, 3030, 3031, 3032, 3033, 3034, 3035,
#        3036, 3037, 3038, 3039, 3040, 3041, 3042, 3043, 3044, 3045, 3046,
#        3047, 3048, 3049, 3050, 3051, 3052, 3053, 3054, 3055, 3056, 3057,
#        3058, 3059, 3060, 3061, 3062, 3063, 3064, 3065, 3066, 3067, 3068,
#        3069, 3070, 3071, 3072, 3073, 3074, 3075, 3076, 3077, 3078, 3079,
#        3080, 3081, 3082, 3083, 3084, 3085, 3086, 3087, 3088, 3089, 3090],
#       dtype=int64),)

# %% [markdown]
# ### Anomaly Visualization
# Since we know the index of anomalous data, we can also identify the corresponding timestamps from the test dataset. Below is a simple description of how tihs is achieved.
#
# Let's say sequence_length = 3 and we have 10 training values ( 0 ~ 9 ). Our x_train in the processed form will be as below:
#
# * 0, 1, 2
# * 1, 2, 3
# * 2, 3, 4
# * 3, 4, 5
# * 4, 5, 6
# * 5, 6, 7
# * 6, 7, 8
# * 7, 8, 9
#
# Other than the initial and the final (time_steps-1) data values, all other data will appear in more than one of the sequences of data. Take an example, if these samples [(3, 4, 5), (4, 5, 6), (5, 6, 7)] are anomalies, we can confidently state that the data instance 5 is an anomaly."

# %%
# data i is an anomaly if samples [(i - timesteps + 1) to (i)] are anomalies
anomalous_data_indices = []
for data_idx in range(time_steps - 1, len(test_set) - time_steps + 1):
    if np.all(anomalies[data_idx - time_steps + 1 : data_idx]):
        anomalous_data_indices.append(data_idx)
        
# overlaying anomalies on original test data plot
df_subset = df_daily_jumpsup.iloc[anomalous_data_indices]
fig, ax = plt.subplots()
df_daily_jumpsup.plot(legend=False, ax=ax)
df_subset.plot(legend=False, ax=ax, color="r")

plt.xlabel("Time (in days)")
plt.ylabel("Values")
plt.title("Values of artificial variable against time")

plt.show()

# %% [markdown]
# Source: https://keras.io/examples/timeseries/timeseries_anomaly_detection/
